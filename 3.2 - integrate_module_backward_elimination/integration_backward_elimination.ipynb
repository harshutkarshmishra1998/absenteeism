# %%
from absenteeism_module_backward_elimination import *

# %%
model = absenteeism_model(
    'model_backward_elimination', 'scaler_backward_elimination')
model.load_and_clean_data('absenteeism_new_data.csv')
model.predicted_outputs().head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  Day of the Week  \
# 0         0       0.0         0         1            6                4
# 1         1       0.0         0         0            6                0
# 2         0       0.0         0         1            6                2
# 3         0       0.0         0         1            6                4
# 4         1       0.0         0         0            6                4
#
#    Transportation Expense  Body Mass Index  Education  Children  Pets  \
# 0                     179               19          1         0     0
# 1                     361               27          0         1     4
# 2                     155               25          0         2     0
# 3                     179               22          1         2     0
# 4                     155               25          0         2     0
#
#    Probability  Prediction
# 0     0.115915           0
# 1     0.860867           1
# ...

# %%
model.predicted_outputs().to_csv('absenteeism_predictions_backward_elimination.csv', index=False)
